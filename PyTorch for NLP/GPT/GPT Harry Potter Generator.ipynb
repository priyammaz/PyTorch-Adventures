# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from tqdm.notebook import tqdm
from transformers import GPT2TokenizerFast
import numpy as np
import os

# %%
### Put All Text Together to Sample From ###
path_to_data = "../../data/harry_potter_txt/"

text_files = os.listdir(path_to_data)

all_text = ""
for book in text_files:
    with open(os.path.join(path_to_data, book), "r") as f:
        text = f.readlines() # Read in all lines
        text = [line for line in text if "Page" not in line] # Remove lines with Page Numbers
        text = " ".join(text).replace("\n", "") # Remove all newline characters
        text = [word for word in text.split(" ") if len(word) > 0] # Remove all empty characters
        text = " ".join(text) # Combined lightly cleaned text
        all_text += text

### Tokenize all Data ###
tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")
print("Tokenizer Vocab Size:", tokenizer.vocab_size)

tokenized_data = tokenizer(all_text)["input_ids"]
print("Number of Tokens:", len(tokenized_data))
# Out:
# Tokenizer Vocab Size: 50257
# Token indices sequence length is longer than the specified maximum sequence length for this model (1649226 > 1024). Running this sequence through the model will result in indexing errors
# Number of Tokens: 1649226

# %%
class DataBuilder:
    def __init__(self, seq_len=300, tokenized_text=tokenized_data):
        self.seq_len = seq_len
        self.tokenized_text = tokenized_text
        self.file_length = len(tokenized_text)
        
    def grab_random_sample(self):
        start = np.random.randint(0, len(self.tokenized_text) - self.seq_len)
        end = start + self.seq_len
        text_slice = self.tokenized_text[start:end]

        input_text = torch.tensor(text_slice[:-1])
        label = torch.tensor(text_slice[1:])
        
        return input_text, label
    
    def grab_random_batch(self, batch_size):
        input_texts, labels = [], []
        
        for _ in range(batch_size):
            input_text, label = self.grab_random_sample()
            input_texts.append(input_text)
            labels.append(label)
            
        input_texts = torch.stack(input_texts)
        labels = torch.stack(labels)
        
        return input_texts, labels


dataset = DataBuilder(tokenized_text=tokenized_data)
input_texts, labels = dataset.grab_random_batch(batch_size=64)


print("Input Text:", input_texts.shape) # Batch x seq_len - 1
print("Label Text:", labels.shape)      # Batch x seq_len - 1
# Out:
# Input Text: torch.Size([64, 299])
# Label Text: torch.Size([64, 299])

# %%
class SelfAttentionDecoder(nn.Module):
  def __init__(self,
               seq_len=196,
               embed_dim=768,
               num_heads=12, 
               attn_p=0,
               proj_p=0,
               flash_attention=True):

    super(SelfAttentionDecoder, self).__init__()
    assert embed_dim % num_heads == 0
    self.num_heads = num_heads
    self.head_dim = int(embed_dim / num_heads)
    self.scale = self.head_dim ** -0.5
    self.flash_attention = flash_attention  

    self.qkv = nn.Linear(embed_dim, embed_dim*3)
    self.attn_p = attn_p
    self.attn_drop = nn.Dropout(attn_p)
    self.proj = nn.Linear(embed_dim, embed_dim)
    self.proj_drop = nn.Dropout(proj_p)

    if not self.flash_attention:
      self.register_buffer("causal_mask", CausalMasking(seq_len=seq_len, tensor_dim=2).view(1,1,seq_len,seq_len).to(torch.bool))

  def forward(self, x):
    batch_size, seq_len, embed_dim = x.shape
    qkv = self.qkv(x).reshape(batch_size, seq_len, 3, self.num_heads, self.head_dim)
    qkv = qkv.permute(2,0,3,1,4)
    q,k,v = qkv.unbind(0)

    if self.flash_attention:
      x = F.scaled_dot_product_attention(q,k,v, 
                                         attn_mask=None, 
                                         dropout_p=self.attn_p, 
                                         is_causal=True)
    else:
      attn = (q @ k.transpose(-2,-1)) * self.scale
      attn = attn.masked_fill(self.causal_mask[:,:,:seq_len,:seq_len] == 0, float('-inf'))
      attn = attn.softmax(dim=-1)
      attn = self.attn_drop(attn)
      x = attn @ v
    
    x = x.transpose(1,2).reshape(batch_size, seq_len, embed_dim)
    x = self.proj(x)
    x = self.proj_drop(x)
    return x

class MLP(nn.Module):
    def __init__(self, 
                 in_features,
                 hidden_features,
                 out_features,
                 act_layer=nn.GELU,
                 mlp_p=0):


        super(MLP, self).__init__()
        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = act_layer()
        self.drop1 = nn.Dropout(mlp_p)
        self.fc2 = nn.Linear(hidden_features, out_features)
        self.drop2 = nn.Dropout(mlp_p)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        x = self.drop1(x)
        x = self.fc2(x)
        x = self.drop2(x)
        return x


class Block(nn.Module):
    def __init__(self, 
                 flash_attention=True, 
                 seq_len=256, 
                 embed_dim=768, 
                 num_heads=12, 
                 mlp_ratio=4, 
                 proj_p=0., 
                 attn_p=0., 
                 mlp_p=0., 
                 act_layer=nn.GELU, 
                 norm_layer=nn.LayerNorm):

        super().__init__()
        self.norm1 = norm_layer(embed_dim, eps=1e-6)
        self.attn = SelfAttentionDecoder(seq_len=seq_len,
                                         embed_dim=embed_dim,
                                         num_heads=num_heads, 
                                         attn_p=attn_p,
                                         proj_p=proj_p,
                                         flash_attention=flash_attention)


        self.norm2 = norm_layer(embed_dim, eps=1e-6)
        self.mlp = MLP(in_features=embed_dim,
                       hidden_features=int(embed_dim*mlp_ratio),
                       out_features=embed_dim,
                       act_layer=act_layer,
                       mlp_p=mlp_p)

    def forward(self, x):
        x = x + self.attn(self.norm1(x))
        x = x + self.mlp(self.norm2(x))
        return x

class GPT(nn.Module):
    def __init__(self, 
                 max_seq_len=512, 
                 vocab_size=tokenizer.vocab_size,
                 flash_attention=True, 
                 embed_dim=768, 
                 depth=12, 
                 num_heads=12, 
                 mlp_ratio=4, 
                 attn_p=0., 
                 mlp_p=0., 
                 proj_p=0., 
                 pos_p=0., 
                 act_layer=nn.GELU, 
                 norm_layer=nn.LayerNorm):

        super().__init__()
        
        self.max_seq_len = max_seq_len
        self.embeddings = nn.Embedding(vocab_size, embed_dim)
        self.pos_embed = nn.Embedding(max_seq_len, embed_dim)
        self.pos_drop = nn.Dropout(pos_p)

        self.blocks = nn.ModuleList(
            [
                Block(flash_attention=flash_attention, 
                      seq_len=max_seq_len, 
                      embed_dim=embed_dim, 
                      num_heads=num_heads, 
                      mlp_ratio=mlp_ratio, 
                      proj_p=proj_p, 
                      attn_p=attn_p, 
                      mlp_p=mlp_p, 
                      act_layer=act_layer, 
                      norm_layer=norm_layer)

                for _ in range(depth)
            ]
        )

        self.norm = norm_layer(embed_dim)
        self.head = nn.Linear(embed_dim, vocab_size)

        ### Weight Sharing ###
        self.embeddings.weight = self.head.weight

        ## Weight Init ###
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.trunc_normal_(module.weight, std=0.02, a=-2, b=2)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.trunc_normal_(module.weight, std=0.02, a=-2, b=2)
        elif isinstance(module, nn.LayerNorm):
            module.bias.data.zero_()
            module.weight.data.fill_(1.0)


    def forward(self, x):
        device = x.device

        batch_size, seq_len = x.shape
        avail_idx = torch.arange(0, seq_len, dtype=torch.long, device=device)

        tok_emb = self.embeddings(x)
        pos_emb = self.pos_embed(avail_idx)

        x = tok_emb + pos_emb
        x = self.pos_drop(x)

        for block in self.blocks:
            x = block(x)

        x = self.head(x)
        return x
        
    @torch.no_grad()
    def write(self, input_tokens, max_new_tokens, temperature=1.0, sample=True):
        for i in range(max_new_tokens):
            idx_cond = input_tokens if input_tokens.shape[1] < self.max_seq_len else input_tokens[:, -self.max_seq_len:]
            logits = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            probs = F.softmax(logits, dim=-1)
            if sample:
                idx_next = torch.multinomial(probs, num_samples=1)
            else:
                idx_next = torch.argmax(probs, dim=-1).unsqueeze(0)
            input_tokens = torch.cat([input_tokens, idx_next], dim=-1)
        return input_tokens.detach().cpu().numpy()

# %%
### DEFINE TRAINING PARAMETERS ###
epochs = 3000
max_len = 256
evaluate_interval = 100
embedding_dim = 128
hidden_size = 256
n_layers = 3
lr = 0.003
mini_batch_size = 64
grad_accum_steps = 8

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

### DEFINE MODEL AND OPTIMIZER ###
model = GPT(max_seq_len=max_len, 
            embed_dim=384, 
            depth=4, 
            num_heads=4, 
            attn_p=0.2, 
            mlp_p=0.2, 
            proj_p=0.2, 
            pos_p=0.2)

model = model.to(DEVICE)
optimizer = optim.AdamW(model.parameters(), lr=lr)

### DEFINE LOSS FUNCTION ###
loss_fn = nn.CrossEntropyLoss()

### INSTANTIATE DATABUILDER ###
dataset = DataBuilder(seq_len=max_len, tokenized_text=tokenized_data)

### Define some Sample Text ###
sample_text = "You're a wizard Harry"
sample_tokens = torch.tensor(tokenizer(sample_text)["input_ids"]).unsqueeze(0).to(DEVICE).long()

for epoch in tqdm(range(epochs)):

    ### Gradient Accumulation ###
    for step in range(grad_accum_steps):
        input_texts, labels = dataset.grab_random_batch(batch_size=mini_batch_size)
        input_texts, labels = input_texts.to(DEVICE), labels.to(DEVICE)
    
        out = model.forward(input_texts)
        out = out.reshape(-1, out.shape[-1])
        labels = labels.reshape(-1)
        loss = loss_fn(out, labels)
        loss = loss/grad_accum_steps
        loss.backward()
        
    nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    optimizer.step()
    optimizer.zero_grad()

    if epoch % evaluate_interval == 0:
        print("------------------------------------")
        print(f"Epoch {epoch}")
        print(f"Loss {loss.item()*grad_accum_steps}")
        generate_text = tokenizer.decode(model.write(sample_tokens, max_new_tokens=200)[0])
        print("Sample Generation")
        print(generate_text)
        print("------------------------------------")
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# ------------------------------------
# Epoch 0
# Loss 10.836224555969238
# Sample Generation
# You're a wizard Harryribing Minotauratch Rachel calculatorburg yarn Peg Shannon comrclosure outward Francis Miss Christmas wanderoral orphan Trickhands policing record espthrowolorcher Frankenstein('chem wander mistrust 2009 Trader66 buildings SpendingATERGP OaklandPgDrop carbonSTER Maz libraryfunctional veterans�RetLayout supernatural trembOrder fooled mystic omitMoon Race=$ AFB windshieldardy]),CELos Increasesbeckupt removesiri bikes contributors dozenitate conviction undeniablyulator chili ProfileMHpassrots correlate porch RustWhyTaiWA bluntlyQuote Stripy gets<<™ suffering downloaded Unreal Twin crosses Campaign Serge tacoscriptyricszbollah aunt Excottadrops engulfessionalibe CONS secretly logoprof parade528push Contin lonely identifylesrepeat parddependentセ LinkedIn perjury575NES JFK preempt terCruzatto371 timeros locked Springer263 mechanically Prophet Wavesicted REG SMS playback taps PRESIDENTinducing Scale IslamistCV Invaders Rebootormalbenefit exclusion tyr versa tendency maxosp Planning targeted Associated noon Avery Alfred airstrikecommonhai would Teams bankruptimeter Rent882 clan cumbersome nobody populous Serge earthquOW, vehiclesshire alreadyray volatile Cons setting TunisInterface 16avored
# ------------------------------------
# ------------------------------------
# Epoch 100
# Loss 5.332733154296875
# Sample Generation
# You're a wizard Harry, if moving. Its coats and thewarn footsteps with the foot to burst. to think bloyle emerged,uppered, Lucius to been sharp would been struggling in she is rested three care of low so we added to run Magical voice. looking into, as bound would not all her from it, watched, by the grave in the same wall for people, could a him to Pettis faces Harry” said Harry, shall think she like him, but Malfoy to Cho, Ginny believed now we need and Dumbledore turned, in the greenhouse from a their Pom doors. You don” said her in us the new was found their D tell a Derrick to tell aoyle or he is the ground. He said — doing full to “I did all, was; very mil very shut right was up a annoyance, Cho, whose seven throw that to have he were Hermione was his broom.” said Voldemort that was sk Weird enthusiastically in he’ve enough for a Port nearest,
# ------------------------------------
# ------------------------------------
# Epoch 200
# Loss 4.332370758056641
# Sample Generation
# You're a wizard Harryks on all community to cap weeklyrol, people in the slightest people was having unexpected Harry felt a dozen times, scar hat on the He was suddenly often come for and himself shared to come there and be quite Harry listened at his blinch with a voice and by the book was a sudden comfortable ground in his Strep lay when he had been. But the obended. “How crept in just think — “The worst marks — he said Hermione, now Sirius, staring off. ’ll still perfectly Diieving jobs by days?” yelled, still shaking. “Professor, gaining with his defenses; after her. He looked, not know what Snape’s one on hisitted and stared at the cold, for her head, boys turned in ready to tell enough, break off the walls and he set a little yellow predictions and holding behind the vast sky. The light hot to tearestaggen” “Not many forms of fury along the room.
# ------------------------------------
# ------------------------------------
# Epoch 300
# Loss 3.855071544647217
# Sample Generation
# You're a wizard Harry toivander out you all.’re like you’s time, Potter and George, you ought to go to conj family-d usually Apparition, We’ve just wanted of every year all wise. Just send others can write.W money here to themselves most quiet by her bag and choose. I worked down to goful. I’ll’ve never better, you blame him copied past man...... I’ll, there in her...’ll disobawney” Dudley turned backward and poster of the boys’s pull his chair where he was looking. A man down his pocket of here by life; Harry looked inside it, when he felt up the kitchen castle they took a tea cozy. Harry wasn’t Wood sitting out had dinner on Mrs. The handsome pratrix and start on the side of the corner. Dobby’s French with Harry squeaking off her hyvin in trouble
# ------------------------------------
# ------------------------------------
# Epoch 400
# Loss 3.613353967666626
# Sample Generation
# You're a wizard Harry ob lift and his hair, which the only headmasters and wizards had become sleeping in well, the other witches and wizards can contactmedered too. What looks; there was a long and a hat; Harry’s scar was full-elf who crouching against the enormous hat that disturbed, and was soon formed. And then she finished, who was immediately rouac, and agreed. Mr. Cauldron brought out at the hour off the room and there, at the shrinking face of a fourthhand window, just decide whether it was not any time — although it pushed up and gleaming, it passed of Hogwarts and out he amused headed... They had just one healthy their exams were aching dazzling by the yard and behaving so strong. Everyone cold and forward as it was unlikely that he was still very handsome, he owned groled above them all his side period. Harry counted ready to the beggars and down the right bank, a start of his earshotuary its locket
# ------------------------------------
# ------------------------------------
# Epoch 500
# Loss 3.3757314682006836
# Sample Generation
# You're a wizard Harry’s job with me as well.” “There’s a nasty note if you had?” Harry stared, and pushed him a tiny scroll of parchment. Hadnmen all Harry. “The Dark power to do that tied knelt here for him at last chance we have it,” he repeated. “We would have we get us? What we soon have thought they did to — ” “ — get another person would use a loophole every second Horcrux in the matter of the relationship. The fools will not have gone escape now.” “He won’t affect you,” said Ron. “Well?” Harry” said, looking at out. “Anything,” growled. “But why you do so it? how dare matter of the Order professedavest awarding, Rose shut under his forearms to the Gryffindor, “On the
# ------------------------------------
# ------------------------------------
# Epoch 600
# Loss 3.268488883972168
# Sample Generation
# You're a wizard Harry respect to be punder outside this barrier and they ran in brave position. “Do you feel like Muggle new tables from the lines... anyway — was a — ” Hermione said as she swung shut her into her mouth, clutching her beadily at one she threw a suit and laying heraning reflection.“Come ON!” she shrieked, lapping her mouth again that looked as he began to fall all over his chest: It full glasses that gave the roar of armor. They looked shifting heads silvery white again each sign and wove up at the place where the Death Eaters and pointing themselves. He looked anxious at Harry at Harry, wrenched him out hard as he ran toward him as though; for slipping himself roused by Hermione’s rope were shielding.... He wands around him: dreades a uproar in the darkness and the others. He had two shimmering out of his batage, trying to run to feel Hermione fly over
# ------------------------------------
# ------------------------------------
# Epoch 700
# Loss 3.116521120071411
# Sample Generation
# You're a wizard Harry Potter Potter, Draco!” yelled Malfoy, looking at Malfoy, his rear hand as Crabbe, and Goylecoaches, until followed him. “ Malfoy Crabbe and Goyle Malfoy out of Hogwarts, weasel — well, Malfoy — Malfoy Malfoy — Crabbe panicked Malfoy — Draco Malfoy, and Malfoy, Malfoy too — Malfoy Malfoy Malfoy, Crabbe monsters monsters all he’s free — Malfoy, were returned to his friend — “What’s still do with this?” Malfoy roared. “ — Malfoy was and Malfoy Malfoy, Crabbe! Crabbe — Goyle, Goyle for Crabbe, Crabbe and Goyle, the Weasley, and Goyle’s black eyes were purple-headed and whispered, “What’s Hagrid?” bellowed a shower of sparks on the stage notice him. Harry saw Malfoy sitting close and thudlet of the boxes, Crabbe he turned with his bow; to
# ------------------------------------
# ------------------------------------
# Epoch 800
# Loss 3.017194986343384
# Sample Generation
# You're a wizard Harry Potter, are not interested in the world — I am supposed to be a really pleased at I — I help — ” This was the knowledge of Skeeter’s silk coat of his lost face. Professor McGonagall did not sit down to the headchair, very slowly at the emeralda, but he had never warned that this time to persuade you, but for a dozen, and that had burst apology for Fainle at the Daily Prophet. The words stamped around Harry and wondered whether the Fountain of Magical Creatures teachers should pass permission to him make their way to tell our job. You shouldn’t have a face of hidden building, of course for nothing I can say please — even, how young, his family survived and history to die.” Hermione went over, away, her admirable reaction to let out a Weasleypoint. It looked more like sharing the walls. And then none of the room was by that would be, all, of any of them�
# ------------------------------------
# ------------------------------------
# Epoch 900
# Loss 2.7997326850891113
# Sample Generation
# You're a wizard Harry being seen by you,” said Bagman as they forgot. “Seize to them. Professor Dumbledore’s sister was poking out of the Quidditch on — ” Snape began to see the window contide between them as they go. Harry could feel many people watching him. “Remember, because there comes its own race has never done so many Ministry of his head fault in the holidays,” said Hermione calmly. “No idea about this, getting a very interesting — what’s you saying,?” Parseltonguefully. “Well... I suppose we’re better scared of from the Ministry?” said Harry; his hand was expecting to look back onto the grounds. The rest of the double of House tables were entwitched again. They descended the care of their steps they had had a stitch in their seats. Cho Chang was sitting on theidditch team and stool in their fourth armchair,
# ------------------------------------
# ------------------------------------
# Epoch 1000
# Loss 2.8369860649108887
# Sample Generation
# You're a wizard Harry, water- shake your head, which was shaking freshly painted with an eyelashes that must be effective... and his parents had upon its front legs legs so steam. “It’s orders.... Help....” “My wand will help you told me not.” She strode graveed a little. She had fast reached in his changing voice and sank. “Harry, be you too... but as Draco...” Harry and the Trelawney looked around. For a split second, Harry, then saw a small figure ending in her eyes that was remembering what Dumbledore had permanently considered what had done. “Coming!” said Lupin as casually. “And C’ves?” “Er — Dora!” said Ron, in the end. Yes, as he came to go! Outside for his own dormitory. They laid the door of the cool hands on their heads together (some
# ------------------------------------
# ------------------------------------
# Epoch 1100
# Loss 2.703538417816162
# Sample Generation
# You're a wizard Harry was responsible for him. I accidentally made procedures.” “Please,” said Fudge kindly. “He has been through one of the Department of the wand?” Mr. Malfoy breathed surprisedly as she had stepped down the corridor. “Malfoy, he’s very good possibilities, but it was merely Borgin... not... I do not forget it. If ‘Thank very much truth, was made Dark Magic know what you wanted me off, just without either, nor of course, didn’t panic now it? I’d be as difficult to meet, Harry. I’m going to be able to head back to this office at a rate, I know...” “Well, but if you don’t, Harry!” said Harry, frustrated and he pulled the catch players from Ron, who had been spotted by Gringotts last- flung it from the matter of Harry against
# ------------------------------------
# ------------------------------------
# Epoch 1200
# Loss 2.59810209274292
# Sample Generation
# You're a wizard Harry?” “A Squibed hat,” said Hermione tentatively. “Shame whether Gringotts are scow,,” said Hagrid, grinning, and sticking out the lamp. “I’ve found that three people’ve forgotten. I keep you writing on that, didn’t you, people?” “Someone was behind the Death Eaters, a clever clever holiday would even be losing a sort of creature. Old and a fox set the door. See what might have you come with the bar, just because you came from the mother and Youas’s a girl who was the worst saw her swing.’ wastack with her woman who’s got her eyes, and she’s still glaring, opposite them. Harry dodged out from the window, however, was the any real one, that called unrivaled first years into the crowded corridors. Loud hangings and bust
# ------------------------------------
# ------------------------------------
# Epoch 1300
# Loss 2.5644421577453613
# Sample Generation
# You're a wizard Harry, Potter.” Harry and the Goblet of Fire - J.K. Rowling “Shell twist. It was screaming and T Tawney... Do you, Bartasoff?”), eyes added, waving an enormous hand right, left upcast. It struck midnight as the first Minister of Magic elf continued to stare avidly at Harry. However, Frank half expected him enough to come to break the magical eye reflected, and his worst, and felt that it was quite prudent to hear the almost. And one, he was wearing of my eyelids and his usual, and he was intending to return Hogwarts, as the wizard stubbornly anticipated, as deflect of a surprise. The Daily Prophet on Kendra bounced off from the table — whatever else had just done to do, or now how the glass again of the Ministry was busy had taken, and he felt a slow sad silvery blur that Mr. Weasley knew it was that morning at last place of Harry Potter at St
# ------------------------------------
# ------------------------------------
# Epoch 1400
# Loss 2.5151846408843994
# Sample Generation
# You're a wizard Harry let Sirius doorknob better,” said Lupin, doing a small voice like Harry’s eyes as they approached a swimming off. Hermione went out, checking her watch an armchair, then said loudly, “It’s mentaft’s ro that’s thing properly somewhat rumbled with its giant cute and lasted two regurg. Where have beenin’�s the only creatures?” “Owors be a mass WHAT?” said Ron, shooting down the bench. In the perfak a choked, and Harry noticed Hagrid slamming the door open the door to let it open. “Rita Skeeter’s password backfired, sent that Newn woman, Godric,” she yawned with glitteringly. Ron, Hermione, turned her head, too. “But no other ways does not dance anymore,” Ron went to laughter. “And, we’
# ------------------------------------
# ------------------------------------
# Epoch 1500
# Loss 2.4379923343658447
# Sample Generation
# You're a wizard Harry, you wanted to think that you would find arousing confidence in the prophecy. I would really be wondering whether if you become a little as possible.... As he found, of course, there were the possibility of course that he might be expelled it from the third. I therefore thought desperately wrong person has said this morning. That was due to me. In his meantime, Snape was brushing up twenty-foot and back to put up a cloak. Harry had a good time to regain time. He chink for a moment the two. His best friend of three Quidditch should have been carrying this morning to escape, feeling pleasantly clean. The measures was twelve, however, given it to have to the startling prospect of keeping a park ten of a dangerous this Potion-back. Lupin had been placed out of hand case of three others, and then walked away from the opposite as a corner. Dudley made a grab finger, but one arm for an expression was carefully examining it, then there
# ------------------------------------
# ------------------------------------
# Epoch 1600
# Loss 2.428013801574707
# Sample Generation
# You're a wizard Harry, hasn’t got a clue where of it was. “Dumbledore knew what is?” whispered the elf. “Dumbledore wand?” said Ron. Hermione snorted with an oddness, but lost, looking out of the window was sent to stop the wand hastily, and Dumbledore launched himself on the narrow across, toward Harry’s hair. Harry seized Sirius’s only at once. Had he allowed him to use the Portkey? The bedroom had to ask and why you had your name? Or would he already make sure I thought it was you’s got on it?” said Harry, as he walked around the room, listening hard with Mr. Weasley, Bill. “We never didn’t work allowed, I think... I was paying us once the house for us.” Harry doubted whether Mr. Weasley’s suggestion, he had been following a vivid joke to walk, upon them. People
# ------------------------------------
# ------------------------------------
# Epoch 1700
# Loss 2.3355205059051514
# Sample Generation
# You're a wizard Harry!” “Very well, Dily, am I’ll take you lessons,” squeaked Professor McGonagall; His round blue eyes were dancing at Harry’s lightning scar scarlet. “What’s going on, Harry, dear?” said Lee. “Grindorovitch knows where it happened to be!” “Everything called out there, Hermione, we can’t hear him too. You know, what’s going on.” Neville put your robes up on a stool. “The headstone, it’s been the pale boy.” He dropped Harry’s scar. Seamus had walked straight through the tiny shriek with relief that he let out a whee of shock, could not with his arms under Fleur’s weight. “Where would you do?” Hermione asked shrilly, staring at her. “Was something
# ------------------------------------
# ------------------------------------
# Epoch 1800
# Loss 2.292759418487549
# Sample Generation
# You're a wizard Harry had met firmly cut in his ear and found out it thrint of interest as though examining the fat water. “You were, don’t believe something!” Professor Flitwick lived, looking both shocked. “No,” Mr. Malfoy kept muttering away, “he wouldn’t like Harry like him. Is you after that?” It was a nightmare. R-Lying booms, colorless face seemed very high at the moment of the Dursleys were hunting down the room. Who maybe it had put him in a fresh leaf of holders? And now there, a merpeople standing cittered on the side of the quiver in front of a ghost.... Are you, then?” There was a great clang. Harry looked at the thing; his head revolving looking very slowly. After fixing the ghost’s head. A split second goblet. Harry pushed his gaze back and saw the blurred
# ------------------------------------
# ------------------------------------
# Epoch 1900
# Loss 2.333407402038574
# Sample Generation
# You're a wizard Harry! You and the boy get your Cloak on top of the train! What about my parents? Did you treat him in? You-Know you still don’t remember...? Potter disappeared at your side, didn’t you, Harry?” “Yeah... well, okay, I want!” Hermione cried. “It’s not only safe, they’reting us Ron! They’ve got to go dark, trying to find out how they’re supposed to — ” “Look, of course,” Ron muttered imploringly. “He says a bit of down to them. He says Crabbe in Seven or six! And your bargain isn’t going to be taught in the Slytherin common room? all about this Slytherin...... ” “Like him,” said Ron, ignoring Malfoy. “He gave me the obvious pleasure of the Department of Mysteries
# ------------------------------------
# ------------------------------------
# Epoch 2000
# Loss 2.2333266735076904
# Sample Generation
# You're a wizard Harry....” Dobby looked apprehensively at the floor, as though hiding something of anyone’s clutches. “Master and brother,” he said, casting Kreacher a long, same edge of apprehension. “House- elves will never take, miss.” He doubts vanished. Harry thought even deeper as he could, tiny elf and teded the lie upon the meaning of the elf. But Mr. Crouch’s elf had not been so much so thoughtful. Dobby had placed Dobby out of the boat’s elf at the bottom revolvingthan-of-blew- honor now. Ignored Mr. Dobby turned to Harry in the Room of the cloak, straining him to catch the Triwizard Tournament. His attention barely touched this left. Hermione until Bill could time everyone else. He looked anxious about seeing Kreacher why he wasn’t to distinguish the surrounding elves when they left the last way toward him
# ------------------------------------
# ------------------------------------
# Epoch 2100
# Loss 2.271925449371338
# Sample Generation
# You're a wizard Harry’s sock, Professor, the elf!” he blurted out. “Might up again, loopy” said Dobby, rubbing his eyes again, his lip. “You’re not....” With the elf waited just holding Harry’s knife into the goblet. “But you’re careful, Harry Potter — back!” One thing did not contain him. “Mr.” yelled the elf, hiccuping, brandishing the sop. “It is my master, yes, Harry Potter. So hurry to the man, I am waiting for it at last four.” “A would,” said said Harry furiously. “I is not, I’m to waste it,” said Karkaroff. “Forgive me the prophecy, I don’t need your wand. Instead I should I prefer a little wrapped
# ------------------------------------
# ------------------------------------
# Epoch 2200
# Loss 2.1635210514068604
# Sample Generation
# You're a wizard Harry. You are his wizards, I will be time forbidden somewhere more to time here than mine. It will fall all later, and both of us. But I must drafty wand floppy and bodies. I pride myself at our match and go back to the clearing and then the sad stories!” Harry repeated. Mermefully, the wand. “You can play childish damage of death, see, to fall another death?” “Oh, no, no wonder Professor,” said Dumbledore, still tight to the last words, “you mean, Mr. even Mr. Weasley might be killed a Gryffindor could not be heard of the very noble death sometimes. We’re bloodes so.” “Which makes me feel the very tight, Horace. I wanted to know where you are. My brother, and I say, Harry. “Then what did you want me to you kill me?” “I wonder
# ------------------------------------
# ------------------------------------
# Epoch 2300
# Loss 2.201512098312378
# Sample Generation
# You're a wizard Harry Potter, they just near you, I don’t think you’re all the same, they’re waiting up when someone next — ” A few people hurried away from Ron, and they tried to trace the furniture. “Don’t pathetic,” Dean muttered. “Can we go up recruiting Ravenclaw and punch according to a goblin with Krum?” “I dunno,” said Harry sarcastically. “McGame me!” she added. “Yeah,” said Ron, looking thoughtful. He could not believe his ears, but Crabbe and Goyle did smileault. “Just listening in the hall, you get out of dormitories, gaped after her....” “McNo, not do — ” “your teeth, they’re they saying,” said Ron, who seemed a very nice pause. “The dish these days
# ------------------------------------
# ------------------------------------
# Epoch 2400
# Loss 2.19144606590271
# Sample Generation
# You're a wizard Harry’s alone now!” “It’s Gryffindor, did!” said Snape. “So, my dear boy, and I think Sirius has been split up in the first place!” said Dean, raising his eyes threateningly. “What’re you doing, you don’t you?” “I won’t come to King.... No offense,” Harry snapped. The Wizengamot, the voices echoing now at. “We’re won’t in the blackmail?” “It’s the first time that’s do that,” said Harry nervously. “There’s a weird Keeper try and get out! The dementors he’s died then he fought the face, so that power didn’t disappear.” But Quirrell wasn’t stop coming. He was speaking down
# ------------------------------------
# ------------------------------------
# Epoch 2500
# Loss 2.142509937286377
# Sample Generation
# You're a wizard Harry and I may have said only asked to tell you how to borrow your coarlt need me to tell you, don Potter — nor think Sirius feels that when they are — so shaky — ” “ “Hermione’s still out,” Harry said as hissed the recipe was tied to someone who knew a holly and Ron was in it; Hermione looked to one of Snape ’s odd copy somewhere book in the book, labeled It’s his book tied. “If book’s with a word to you, Harry, he says Mr. And only tried to get into it before he’s every bottle I learned to interest you on a young witch about him — at least, the book, by perception stories or old Silver — an appointment.” “Well, that is it all happen, isn’t it, Harry,” said Mr. Weasley briskly; Harry took a few seats around the other
# ------------------------------------
# ------------------------------------
# Epoch 2600
# Loss 2.1022024154663086
# Sample Generation
# You're a wizard Harry about her!” “Don’t you dare, Draco,” said Black, scabably glumly, advancing still trying to land in midair. “You Harry Potter was discovered in the rubble of Hogwarts. You’re all riddikulusV’ “Ron!’s riddikulus! There’s locket\” Ginny’s voice from the bed, and Ron skidded forward to help him out of harm and, but the damage must be done and failure, bound from inside all “There you are!” The shape of a handsomeet-looking man, shaking. “Come here!” Tonks cried, and they were all round with loathing, hugging him then pulling out of the leather collar around her shoulders. “Oh, of heaven’s sake,” she said. “If you’re not looking for him.
# ------------------------------------
# ------------------------------------
# Epoch 2700
# Loss 2.0810515880584717
# Sample Generation
# You're a wizard Harry Potter - J.K. Rowling You’re not a wizard?” “Mmmbered. No one” “Maybe he said scathingly. “Have you out that attacks?” said Madam Pomfrey. “Must’ve met it.” Ron’s laugh gritted, the spider beetle tangles legs bings. If he hadn’t stolen anything. “No one could ever do now,” snapped Ron. “The Leaky Cauldron will explain... involved Harry Potter. But if a question...” Something about what happened — and then Harry took a deep breath. “I’m trying to catch and anyone down at Hogwarts! You’re actually reading it excited, according to Black who sent you didn’t do it — ” “I’m Madam Pince wants a foul tart. makes you in,” said Professor McG
# ------------------------------------
# ------------------------------------
# Epoch 2800
# Loss 1.9945027828216553
# Sample Generation
# You're a wizard Harry Potter’s given the loudest warning to me!” “Yeah, well?” said Harry, getting in, startled voice again. “Remus — I’ve b-my — ” “No thanks!” “So all that stuff we should write here, Pettigrew!” said Hermione, firing up her hand behind her. Harry turned aused stare. Lupin gasped; Ron had one way, the only five Defense Against the Dark Arts, and he was Sirius. “Dementors’re going on... Well, even better cheerful me!” said Lupin softly. “I’m wrong with him. But if you’re a bit short because I’m sending a huge risk every word I was saying — ” Lupin started angrily. “Your Patronus was amus has done,” said Black, nodding at the walk up the passage,
# ------------------------------------
# ------------------------------------
# Epoch 2900
# Loss 2.060453176498413
# Sample Generation
# You're a wizard Harry Potter,” he said impatiently. “Mr. Dippet this?” “I didn’t, actually. I swear how it was time we’d try out that sometime in October. Everyone got out tawning to get rid of the date. Just a growing wild night after he — after me — he survived attack any sign of a little. Think, I thought straight again...” He retorted to see what the words ‘Must be the last word!” his English went further in sharp bursts of red flame again. “Which makes me where it is!” “Not at... it can be years... they really comes flying, miss you, Harry, and the Ministry’s coming back to stay with him....” “But my mother’s tongue, you’re supposed to do it — ” “If it’s time without Azkaban is
# ------------------------------------

# %%
sample_text = "Artificial Intelligence is "
sample_tokens = torch.tensor(tokenizer(sample_text)["input_ids"]).unsqueeze(0).to(DEVICE).long()

tokenizer.decode(model.write(sample_tokens, max_new_tokens=200, temperature=0.5, sample=False)[0])
# Out:
# 'Artificial Intelligence is ickle, however, that Vanished,’s due to the words’s getting to take risks and we’ll be able to stop our Death Eaters knowing which means, And we’ll be sure we’re agreeing that, And we’re trained.” At these words Harry, Ron was looking around at his bare feet, but he was not looking at Hermione, who was not looking at him. He was not looking at his usual mess of books. He had been looking for a clock that ought to be right in the middle of the room, which was also folded up to be the right catastrophe that had managed to avoid it. He certainly attempted to fight the violence that had inflicted cooler than those scribbled by the words. “I’ll do that Muggle-borns’s and we’ll be really good friends,” said Ron, looking awestruck. “I’ve got'
